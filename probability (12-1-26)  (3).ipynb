# %%
import numpy as np
cricket_score=[10,12,15,100]
print(np.mean(cricket_score))
# Out:
# 34.25

# %%
score=[12,16,20,45]
print(np.mean(score))
# Out:
# 23.25

# %%
import numpy as np
cricket_scores=[10,12,15,100]
median_score=np.median(cricket_scores)
print(f"median:{median_score}")
# Out:
# median:13.5

# %%
from statistics import mode
votes=[1,2,2,3,4]
most_common=mode(votes)
print(most_common)
# Out:
# 2

# %%
from statistics import mode
votes=[1,2,2,3,3,4,5,6,6,7,8,9,9,9,10]
most_common=mode(votes)
print(most_common)
# Out:
# 9

# %%
import numpy as np
tight_data=[60,70,80]
spread_data=[20,70,120]

print("tight std:",np.std(tight_data))
print("spread std:",np.std(spread_data))
# Out:
# tight std: 8.16496580927726
# spread std: 40.824829046386306

# %%
import random
#simulating random predictions
for i in range (5):
  prediction =random.choice(["spam","not spam"])
  print(f"email{i+1}:{prediction}")
# Out:
# email1:spam
# email2:spam
# email3:spam
# email4:not spam
# email5:not spam

# %%
import random
#simulate 10 dice rolls
samples = [random.randint(1,6)
 for _ in range(10)]
print("sample rolls:",samples)
print("samples mean:",sum(samples)/len(samples))
# Out:
# sample rolls: [6, 4, 5, 5, 4, 1, 2, 2, 3, 4]
# samples mean: 3.6
